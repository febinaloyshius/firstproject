# %% [markdown]
# # Hands-on 1 -- Build a Student Result Checker
#
# ---

# %% [markdown]
# ## Objective
#
# Build a simple interactive Python program using:
#
# - Variables
# - Data types
# - Input / Output
# - Operators
# - Conditions

# %% [markdown]
# ## Introduction
#
# Every useful program follows a simple pattern:
#
# **Input --> Store Data --> Process --> Make Decision --> Display Result**
#
# In this notebook you will apply each part of that pattern to build a working Student Result Checker from scratch.

# %% [markdown]
# ## Scenario
#
# You are creating a simple college **Student Result Checker**.
#
# The application should:
#
# 1. Ask for the student's name.
# 2. Ask for marks.
# 3. Store the information.
# 4. Check the result.
# 5. Display the final result.

# %% [markdown]
# ---
#
# ## Step 1 -- Collect Student Information
#
# The `input()` function lets your program ask the user to type something.
#
# - `input()` always returns a **string** (text).
# - To work with numbers, wrap the input in `int()` to convert the text into an integer.
#
# Run the cell below and type your responses when prompted.

# %%
# Collect student name and marks
name = input("Enter student name: ")
marks = int(input("Enter marks: "))

# Display the stored values
print("Student:", name)
print("Marks:", marks)
# Out:
# Enter student name: jam
# Enter marks: 20
# Student: jam
# Marks: 20

# %% [markdown]
# **Expected Output** (if the user enters `Asha` and `82`):
#
# ```
# Student: Asha
# Marks: 82
# ```
#
# Notice that `name` is a **string** and `marks` is an **integer**. Python stores each value with the correct data type so you can use it later.

# %% [markdown]
# ---
#
# ## Step 2 -- Apply a Condition
#
# Now we need the program to make a decision: did the student pass or fail?
#
# - `if` checks whether a condition is `True`.
# - `else` runs when the condition is `False`.
#
# The comparison operator `>=` means "greater than or equal to".

# %%
# Determine pass or fail
if marks >= 50:
    print("Result: Pass")
else:
    print("Result: Fail")

# %% [markdown]
# **How it works:**
#
# - Python evaluates `marks >= 50`.
# - If the expression is `True`, the indented code under `if` runs.
# - If it is `False`, the indented code under `else` runs.
#
# Only **one** branch executes -- never both.

# %% [markdown]
# ---
#
# ## Step 3 -- Add Result Categories
#
# A simple pass/fail is not enough. Let us add a third category: **Distinction** for students who score 75 or above.
#
# `elif` (short for "else if") lets you check additional conditions between `if` and `else`.

# %%
# Categorize the result
if marks >= 75:
    result = "Distinction"
elif marks >= 50:
    result = "Pass"
else:
    result = "Fail"

print("Result:", result)

# %% [markdown]
# **Expected Output** (if marks = 82):
#
# ```
# Result: Distinction
# ```
#
# Python checks the conditions from **top to bottom** and stops at the first one that is `True`.

# %% [markdown]
# ---
#
# ## Step 4 -- Display the Final Result
#
# Combine everything into a clean final display showing the student's name, marks, and result.

# %%
# Display the complete student report
print("===== Student Result =====")
print("Name  :", name)
print("Marks :", marks)
print("Result:", result)
print("=========================")

# %% [markdown]
# **Expected Output** (if name = Asha, marks = 82):
#
# ```
# ===== Student Result =====
# Name  : Asha
# Marks : 82
# Result: Distinction
# =========================
# ```

# %% [markdown]
# ---
#
# ## Reflection Question
#
# **What happens if the user enters text such as "eighty" instead of the number 80?**
#
# Try it. Run Step 1 again, type a word instead of a number for marks, and observe the error message Python produces. Think about why this happens -- we will revisit this topic in a later session.

# %% [markdown]
# ---
#
# ## Final Challenge
#
# Extend the Student Result Checker to handle **3 subjects**.
#
# Your program should:
#
# 1. Accept the student's name.
# 2. Accept marks for **3 subjects** (e.g., Math, Science, English).
# 3. Calculate the **average** of the 3 marks.
# 4. Determine the result based on the average:
#    - Average >= 75 --> Distinction
#    - Average >= 50 --> Pass
#    - Average < 50  --> Fail
# 5. Print a **formatted student report** showing each subject, the average, and the result.
#
# Write your solution in the cell below.

# %%
# --- Your solution here ---
# 1. Accept the student's name.
student_name = input("Enter student's name: ")

# 2. Accept marks for 3 subjects.
math_marks = int(input("Enter Math marks: "))
science_marks = int(input("Enter Science marks: "))
english_marks = int(input("Enter English marks: "))

# 3. Calculate the average of the 3 marks.
total_marks = math_marks + science_marks + english_marks
average_marks = total_marks / 3

# 4. Determine the result based on the average:
#    - Average >= 75 --> Distinction
#    - Average >= 50 --> Pass
#    - Average < 50  --> Fail
if average_marks >= 75:
    final_result = "Distinction"
elif average_marks >= 50:
    final_result = "Pass"
else:
    final_result = "Fail"

# 5. Print a formatted student report showing each subject, the average, and the result.
print("\n===== Student Report =====")
print(f"Name          : {student_name}")
print(f"Math Marks    : {math_marks}")
print(f"Science Marks : {science_marks}")
print(f"English Marks : {english_marks}")
print(f"Average Marks : {average_marks:.2f}") # Format to 2 decimal places
print(f"Result        : {final_result}")
print("==========================")
# Out:
# Enter student's name: jake
# Enter Math marks: 78
# Enter Science marks: 69
# Enter English marks: 90
#
# ===== Student Report =====
# Name          : jake
# Math Marks    : 78
# Science Marks : 69
# English Marks : 90
# Average Marks : 79.00
# Result        : Distinction
# ...

# %% [markdown]
# ---
#
# ## Key Takeaway
#
# - **Variables** store information so your program can use it later.
# - **Operators** (such as `>=`, `+`, `/`) process values and produce results.
# - **Conditions** (`if`, `elif`, `else`) allow Python programs to make decisions and follow different paths based on the data.

# %% [markdown]
# ---
#
# ## Notebook Summary
#
# In this notebook you practiced:
#
# - Collecting user input with `input()` and converting it with `int()`.
# - Storing data in variables with appropriate data types.
# - Using comparison operators to evaluate conditions.
# - Controlling program flow with `if`, `elif`, and `else`.
# - Displaying formatted output with `print()`.
